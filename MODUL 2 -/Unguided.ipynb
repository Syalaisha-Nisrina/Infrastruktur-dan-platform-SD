# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # 1. Load Data

# %%
import pandas as pd
df = pd.read_csv('Movie_classification.csv')

# %%
df.head(10)
# Out:
#    Marketing expense  Production expense  Multiplex coverage     Budget  \
# 0            20.1264               59.62               0.462  36524.125
# 1            20.5462               69.14               0.531  35668.655
# 2            20.5458               69.14               0.531  39912.675
# 3            20.6474               59.36               0.542  38873.890
# 4            21.3810               59.36               0.542  39701.585
# 5            20.5970               59.36               0.542  35718.650
# 6            21.7658               70.74               0.476  33396.660
# 7            22.8910               70.74               0.476  34285.460
# 8            24.2248               70.74               0.476  31280.205
# 9            23.4008               70.74               0.476  33352.220
#
#    Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# 0         138.7               7.825                8.095            7.910
# ...

# %%
df.tail()
# Out:
#      Marketing expense  Production expense  Multiplex coverage     Budget  \
# 501            21.2526               78.86               0.427  36624.115
# 502            20.9054               78.86               0.427  33996.600
# 503            21.2152               78.86               0.427  38751.680
# 504            22.1918               78.86               0.427  37740.670
# 505            20.9482               78.86               0.427  33496.650
#
#      Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# 501         142.6                8.68                8.775            8.620
# 502         150.2                8.78                8.945            8.770
# 503         164.5                8.83                8.970            8.855
# 504         162.8                8.73                8.845            8.800
# 505         154.3                8.64                8.880            8.680
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Marketing expense    506 non-null    float64
#  1   Production expense   506 non-null    float64
#  2   Multiplex coverage   506 non-null    float64
#  3   Budget               506 non-null    float64
#  4   Movie_length         506 non-null    float64
#  5   Lead_ Actor_Rating   506 non-null    float64
#  6   Lead_Actress_rating  506 non-null    float64
#  7   Director_rating      506 non-null    float64
#  8   Producer_rating      506 non-null    float64
#  9   Critic_rating        506 non-null    float64
#  10  Trailer_views        506 non-null    int64
#  11  3D_available         506 non-null    object
#  12  Time_taken           494 non-null    float64
#  13  Twitter_hastags      506 non-null    float64
#  14  Genre                506 non-null    object
# ...

# %%
df.describe().T
# Out:
#                      count           mean           std          min  \
# Marketing expense    506.0      92.270471    172.030902      20.1264
# Production expense   506.0      77.273557     13.720706      55.9200
# Multiplex coverage   506.0       0.445305      0.115878       0.1290
# Budget               506.0   34911.144022   3903.038232   19781.3550
# Movie_length         506.0     142.074901     28.148861      76.4000
# Lead_ Actor_Rating   506.0       8.014002      1.054266       3.8400
# Lead_Actress_rating  506.0       8.185613      1.054290       4.0350
# Director_rating      506.0       8.019664      1.059899       3.8400
# Producer_rating      506.0       8.190514      1.049601       4.0300
# Critic_rating        506.0       7.810870      0.659699       6.6000
# Trailer_views        506.0  449860.715415  68917.763145  212912.0000
# Time_taken           494.0     157.391498     31.295161       0.0000
# Twitter_hastags      506.0     260.832095    104.779133     201.1520
# ...

# %% [markdown]
# # 2. Cek Nilai Duplikat

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Pada data movie classification tidak terdapat nilai dupliat

# %% [markdown]
# # 3. Menemukan Null Values dalam Bentuk Presentase

# %%
df.isna().sum()/len (df)*100
# Out:
# Marketing expense      0.000000
# Production expense     0.000000
# Multiplex coverage     0.000000
# Budget                 0.000000
# Movie_length           0.000000
# Lead_ Actor_Rating     0.000000
# Lead_Actress_rating    0.000000
# Director_rating        0.000000
# Producer_rating        0.000000
# Critic_rating          0.000000
# Trailer_views          0.000000
# 3D_available           0.000000
# Time_taken             2.371542
# Twitter_hastags        0.000000
# Genre                  0.000000
# Avg_age_actors         0.000000
# Num_multiplex          0.000000
# Collection             0.000000
# Start_Tech_Oscar       0.000000
# dtype: float64

# %%
df.isnull().sum()
# Out:
# Marketing expense       0
# Production expense      0
# Multiplex coverage      0
# Budget                  0
# Movie_length            0
# Lead_ Actor_Rating      0
# Lead_Actress_rating     0
# Director_rating         0
# Producer_rating         0
# Critic_rating           0
# Trailer_views           0
# 3D_available            0
# Time_taken             12
# Twitter_hastags         0
# Genre                   0
# Avg_age_actors          0
# Num_multiplex           0
# Collection              0
# Start_Tech_Oscar        0
# dtype: int64

# %% [markdown]
# Terdapat 12 data dengan missing value yang terdapat pada kolom 'Time_taken' dengan presentase sebesar 2,37 %

# %% [markdown]
# # 4. Drop Missing Values

# %% [markdown]
# **- Berdasarkan Baris**

# %%
# Drop Missing value berdasarkan baris
df_drop_rows = df.copy(deep=True)
drop_baris = df_drop_rows.dropna(axis=0)

# %% [markdown]
# **- Berdasarkan Kolom**

# %%
# Drop missing value berdasarkan kolom
df_drop_columns = df.copy(deep=True)
drop_kolom = df_drop_columns.dropna(axis=1)

# %% [markdown]
# **- Imputasi Mean**

# %%
mean_imputation = df.copy(deep=True)
mean_imputation['Time_taken'] = mean_imputation['Time_taken'].fillna(mean_imputation['Time_taken'].mean())
mean_imputation.isna().sum()
# Out:
# Marketing expense      0
# Production expense     0
# Multiplex coverage     0
# Budget                 0
# Movie_length           0
# Lead_ Actor_Rating     0
# Lead_Actress_rating    0
# Director_rating        0
# Producer_rating        0
# Critic_rating          0
# Trailer_views          0
# 3D_available           0
# Time_taken             0
# Twitter_hastags        0
# Genre                  0
# Avg_age_actors         0
# Num_multiplex          0
# Collection             0
# Start_Tech_Oscar       0
# dtype: int64

# %% [markdown]
# **- Imputasi dengan Modus**

# %%
modus_imputation = df.copy(deep=True)
modus_imputation['Time_taken'] = modus_imputation['Time_taken'].fillna(modus_imputation['Time_taken'].mode()[0])
modus_imputation.isna().sum()
# Out:
# Marketing expense      0
# Production expense     0
# Multiplex coverage     0
# Budget                 0
# Movie_length           0
# Lead_ Actor_Rating     0
# Lead_Actress_rating    0
# Director_rating        0
# Producer_rating        0
# Critic_rating          0
# Trailer_views          0
# 3D_available           0
# Time_taken             0
# Twitter_hastags        0
# Genre                  0
# Avg_age_actors         0
# Num_multiplex          0
# Collection             0
# Start_Tech_Oscar       0
# dtype: int64

# %% [markdown]
# **- Imputasi dengan Median**

# %%
median_imputation = df.copy(deep=True)
median_imputation['Time_taken'] = median_imputation['Time_taken'].fillna(median_imputation['Time_taken'].median())
median_imputation.isnull().sum()
# Out:
# Marketing expense      0
# Production expense     0
# Multiplex coverage     0
# Budget                 0
# Movie_length           0
# Lead_ Actor_Rating     0
# Lead_Actress_rating    0
# Director_rating        0
# Producer_rating        0
# Critic_rating          0
# Trailer_views          0
# 3D_available           0
# Time_taken             0
# Twitter_hastags        0
# Genre                  0
# Avg_age_actors         0
# Num_multiplex          0
# Collection             0
# Start_Tech_Oscar       0
# dtype: int64

# %% [markdown]
# # 5. Eksport Data ke CSV dan Excel

# %%
# Eksport data ke csv
df.to_csv('Movie_classification_clean.csv', index=False)

# %%
# Eksport data ke excel
df.to_excel('Movie_classification_clean.xlsx', index=False)
